# %%
from keras.models import load_model
model1=load_model('/content/drive/MyDrive/Colab Notebooks/model.h5')

# %%
from keras.utils import load_img,img_to_array
import matplotlib.pyplot as plt
img=load_img('/content/drive/MyDrive/Colab Notebooks/hinh-con-vit.jpg')
plt.imshow(img)
plt.show()

# %%
img=load_img('/content/drive/MyDrive/Colab Notebooks/hinh-con-vit.jpg',target_size=(32,32))
plt.imshow(img)

# %%
import numpy as np
img=img_to_array(img)
img=img.reshape(1,32*32*3)
img= img.astype('float32')
img=img/255
np.argmax(model1.predict(img),axis=-1)
# Out:
# 1/1 [==============================] - 1s 732ms/step
# array([97])

# %%
from matplotlib.image import imread
folder='/content/drive/MyDrive/Colab Notebooks/hinhtrain'
for i in range(7):
  plt.subplot(3,3,i+1)
  filename=folder+'/vit'+str(i+1)+'.jpg'
  img=imread(filename)
  plt.imshow(img)
s
plt.show()
