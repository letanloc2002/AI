# %%
import pandas as pd
url='http://winterolympicsmedals.com/medals.csv'
data=pd.read_csv(url)
data[(data['Year'] == 2002)&(data['NOC']=='RUS')]
#Quốc gia Nga ở thế vận hội 2002
# Out:
#       Year            City       Sport       Discipline  NOC            Event  \
# 1993  2002  Salt Lake City    Biathlon         Biathlon  RUS     10km pursuit
# 1994  2002  Salt Lake City    Biathlon         Biathlon  RUS             20km
# 1995  2002  Salt Lake City    Biathlon         Biathlon  RUS    4x7.5km relay
# 1996  2002  Salt Lake City  Ice Hockey       Ice Hockey  RUS       ice hockey
# 1997  2002  Salt Lake City     Skating   Figure skating  RUS      ice dancing
# 1998  2002  Salt Lake City     Skating   Figure skating  RUS       individual
# 1999  2002  Salt Lake City     Skating   Figure skating  RUS       individual
# 2000  2002  Salt Lake City     Skating   Figure skating  RUS       individual
# 2001  2002  Salt Lake City     Skating   Figure skating  RUS            pairs
# 2002  2002  Salt Lake City      Skiing  Cross Country S  RUS             10km
# 2003  2002  Salt Lake City      Skiing  Cross Country S  RUS  15km mass start
# ...

# %%
url='http://winterolympicsmedals.com/medals.csv'
data=pd.read_csv(url)
data1=data[(data['Year'] == 2002)&(data['NOC']=='RUS')]
data1.groupby(['Discipline','Medal','Sport']).count()
# Out:
#                                    Year  City  NOC  Event  Event gender
# Discipline      Medal  Sport
# Biathlon        Bronze Biathlon       2     2    2      2             2
#                 Gold   Biathlon       1     1    1      1             1
# Cross Country S Bronze Skiing         1     1    1      1             1
#                 Gold   Skiing         2     2    2      2             2
#                 Silver Skiing         1     1    1      1             1
# Figure skating  Gold   Skating        2     2    2      2             2
#                 Silver Skating        3     3    3      3             3
# Ice Hockey      Bronze Ice Hockey     1     1    1      1             1

# %%
url='http://winterolympicsmedals.com/medals.csv'
data=pd.read_csv(url)
data1=data[(data['Year'] == 2002)&(data['NOC']=='RUS')]
data1.groupby(['Discipline','Medal','Sport']).count()
#liệt kê số lượng huy chương từng môn
# Out:
#                                    Year  City  NOC  Event  Event gender
# Discipline      Medal  Sport
# Biathlon        Bronze Biathlon       2     2    2      2             2
#                 Gold   Biathlon       1     1    1      1             1
# Cross Country S Bronze Skiing         1     1    1      1             1
#                 Gold   Skiing         2     2    2      2             2
#                 Silver Skiing         1     1    1      1             1
# Figure skating  Gold   Skating        2     2    2      2             2
#                 Silver Skating        3     3    3      3             3
# Ice Hockey      Bronze Ice Hockey     1     1    1      1             1

# %%
url='http://winterolympicsmedals.com/medals.csv'
data=pd.read_csv(url)
data1=data[(data['Year'] == 2002)&(data['NOC']=='RUS')]
data1.groupby(['Discipline','Medal','Sport']).count()
data1.groupby(data1['Medal']).count()
# Out:
#         Year  City  Sport  Discipline  NOC  Event  Event gender
# Medal
# Bronze     4     4      4           4    4      4             4
# Gold       5     5      5           5    5      5             5
# Silver     4     4      4           4    4      4             4
