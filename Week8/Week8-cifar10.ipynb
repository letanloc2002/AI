# %%
from keras.datasets import cifar10
from keras.layers import Dense
import matplotlib.pyplot as plt
from keras import models
from keras.models import Sequential
(x_train,y_train),(x_test,y_test)=cifar10.load_data()

# %%
hinh=x_train[8]
plt.imshow(hinh,cmap=plt.cm.binary)
plt.show
print('so nay la:', y_train[8])
# Out:
# so nay la: [8]

# %%
for i in range(15):
  plt.subplot(3,5,i+1)
  plt.tight_layout()
  plt.imshow(x_train[i],cmap='gray',interpolation='none')
  plt.title('So:{}'.format(y_train[i]))

# %%
model=Sequential()# tuong ANN
model.add(Dense(512,activation='relu',input_shape=(32*32*3,)))
model.add(Dense(10,activation='softmax'))
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 512)               1573376
#
#  dense_7 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 1,578,506
# Trainable params: 1,578,506
# Non-trainable params: 0
# _________________________________________________________________

# %%
x_train= x_train.reshape((50000,32*32*3))
x_train=x_train.astype('float32')/255
x_test= x_test.reshape((10000,32*32*3))
x_test=x_test.astype('float32')/255

# %%
from keras.utils import to_categorical #one hot encoding
y_train=to_categorical(y_train,10)
y_test=to_categorical(y_test,10)

# %%
model.compile(optimizer='rmsprop',loss='categorical_crossentropy',metrics=['accuracy'])
model.fit(x_train,y_train,epochs=10,batch_size=128)
test_loss,test_acc=model.evaluate(x_test,y_test)
print('Do chinh xac tren tap kiem tra: ',test_acc)
print('ham mat mat tren tap kiem tra: ',test_loss)
# Out:
# Epoch 1/10
# 391/391 [==============================] - 9s 21ms/step - loss: 2.2687 - accuracy: 0.2645
# Epoch 2/10
# 391/391 [==============================] - 9s 22ms/step - loss: 1.8011 - accuracy: 0.3538
# Epoch 3/10
# 391/391 [==============================] - 8s 22ms/step - loss: 1.7168 - accuracy: 0.3905
# Epoch 4/10
# 391/391 [==============================] - 8s 20ms/step - loss: 1.6624 - accuracy: 0.4080
# Epoch 5/10
# 391/391 [==============================] - 8s 22ms/step - loss: 1.6231 - accuracy: 0.4237
# Epoch 6/10
# 391/391 [==============================] - 8s 22ms/step - loss: 1.5892 - accuracy: 0.4381
# Epoch 7/10
# 391/391 [==============================] - 8s 20ms/step - loss: 1.5590 - accuracy: 0.4484
# Epoch 8/10
# 391/391 [==============================] - 8s 22ms/step - loss: 1.5409 - accuracy: 0.4558
# Epoch 9/10
# 391/391 [==============================] - 9s 24ms/step - loss: 1.5170 - accuracy: 0.4616
# Epoch 10/10
# 391/391 [==============================] - 9s 22ms/step - loss: 1.4979 - accuracy: 0.4705
# 313/313 [==============================] - 1s 4ms/step - loss: 1.5424 - accuracy: 0.4537
# Do chinh xac tren tap kiem tra:  0.4537000060081482
# ham mat mat tren tap kiem tra:  1.5424379110336304

# %%
from keras.utils import load_img
from keras.utils import img_to_array
from pylab import *
url='oto1.jpg'
img = load_img(url)
imshow(img)

# %%
url='oto1.jpg'
img=load_img(url,target_size=(32,32))
img=img_to_array(img)
img=img.reshape(1,32*32*3)
img=img.astype('float32')
img=img/255
model.predict(img)
# Out:
# 1/1 [==============================] - 0s 44ms/step
# array([[3.7482360e-04, 9.9249351e-01, 4.7856684e-05, 8.5537315e-05,
#         5.1497835e-05, 1.0718689e-04, 3.6844560e-06, 1.4283007e-03,
#         5.7533680e-04, 4.8322110e-03]], dtype=float32)
