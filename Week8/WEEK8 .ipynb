# %%
from keras.datasets import mnist
from keras.layers import Dense
import matplotlib.pyplot as plt
from keras import models
from keras.models import Sequential
(train_images,train_labels),(test_images,test_labels)=mnist.load_data()

# %%
hinh=train_images[100]
plt.imshow(hinh,cmap=plt.cm.binary)
plt.show
print('so nay la:', train_labels[100])
# Out:
# so nay la: [8]

# %%
for i in range(15):
  plt.subplot(3,5,i+1)
  plt.tight_layout()
  plt.imshow(train_images[i],cmap='gray',interpolation='none')
  plt.title('So:{}'.format(train_labels[i]))

# %%
model=Sequential()# tuong ANN
model.add(Dense(512,activation='relu',input_shape=(28*28,)))
model.add(Dense(10,activation='softmax'))
model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_9 (Dense)             (None, 512)               401920
#
#  dense_10 (Dense)            (None, 10)                5130
#
# =================================================================
# Total params: 407,050
# Trainable params: 407,050
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_images= train_images.reshape((60000,28*28))
train_images=train_images.astype('float32')/255
test_images= test_images.reshape((10000,28*28))
test_images=test_images.astype('float32')/255

# %%
from keras.utils import to_categorical #one hot encoding
train_labels=to_categorical(train_labels,10)
test_labels=to_categorical(test_labels,10)

# %%
model.compile(optimizer='rmsprop',loss='categorical_crossentropy',metrics=['accuracy'])
model.fit(train_images,train_labels,epochs=10,batch_size=128)
test_loss,test_acc=model.evaluate(test_images,test_labels)
print('Do chinh xac tren tap kiem tra: ',test_acc)
print('ham mat mat tren tap kiem tra: ',test_loss)
# Out:
# Epoch 1/10
# 469/469 [==============================] - 8s 16ms/step - loss: 0.0135 - accuracy: 0.9955
# Epoch 2/10
# 469/469 [==============================] - 6s 13ms/step - loss: 0.0067 - accuracy: 0.9981
# Epoch 3/10
# 469/469 [==============================] - 4s 10ms/step - loss: 0.0038 - accuracy: 0.9991
# Epoch 4/10
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0024 - accuracy: 0.9995
# Epoch 5/10
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0017 - accuracy: 0.9997
# Epoch 6/10
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0010 - accuracy: 0.9998
# Epoch 7/10
# 469/469 [==============================] - 6s 12ms/step - loss: 5.7944e-04 - accuracy: 1.0000
# Epoch 8/10
# 469/469 [==============================] - 5s 10ms/step - loss: 4.0656e-04 - accuracy: 1.0000
# Epoch 9/10
# 469/469 [==============================] - 5s 11ms/step - loss: 3.2698e-04 - accuracy: 1.0000
# Epoch 10/10
# 469/469 [==============================] - 5s 10ms/step - loss: 2.7105e-04 - accuracy: 1.0000
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0699 - accuracy: 0.9843
# Do chinh xac tren tap kiem tra:  0.9843000173568726
# ham mat mat tren tap kiem tra:  0.06989820301532745

# %%
model.save('model1.h5')

# %%
from keras import models  
model1=load_model('model1.h5')
model1.predict(test_images[51])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-75-aaf06f8fe601> in <module>
#       1 from keras import models
# ----> 2 model1=load_model('model1.h5')
#       3 model1.predict(test_images[51])
#
# NameError: name 'load_model' is not defined

# %%
from keras.utils import load_img
from pylab import *
url='download1.jpg'
img = load_img(url)
imshow(img)

# %%
from keras.utils import img_to_array
url='download1.jpg'
img=load_img(url,target_size=(28,28))
img=img_to_array(img)
img=img.reshape(1,28,28,3)
img=img.astype('float32')
img=img/255
model.predict(img)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-99-697564c5c892> in <module>
#       6 img=img.astype('float32')
#       7 img=img/255
# ----> 8 model.predict(img)
#
# /usr/local/lib/python3.9/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.9/dist-packages/keras/engine/training.py in tf__predict_function(iterator)
#      13                 try:
#      14                     do_return = True
# ---> 15                     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16                 except:
#      17                     do_return = False
#
# ValueError: in user code:
#
#     File "/usr/local/lib/python3.9/dist-packages/keras/engine/training.py", line 2137, in predict_function  *
#         return step_function(self, iterator)
#     File "/usr/local/lib/python3.9/dist-packages/keras/engine/training.py", line 2123, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/usr/local/lib/python3.9/dist-packages/keras/engine/training.py", line 2111, in run_step  **
#         outputs = model.predict_step(data)
#     File "/usr/local/lib/python3.9/dist-packages/keras/engine/training.py", line 2079, in predict_step
#         return self(x, training=False)
#     File "/usr/local/lib/python3.9/dist-packages/keras/utils/traceback_utils.py", line 70, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/usr/local/lib/python3.9/dist-packages/keras/engine/input_spec.py", line 295, in assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Input 0 of layer "sequential_9" is incompatible with the layer: expected shape=(None, 784), found shape=(None, 28, 28, 3)
